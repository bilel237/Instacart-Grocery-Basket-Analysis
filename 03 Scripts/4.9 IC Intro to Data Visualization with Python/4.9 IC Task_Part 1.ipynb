# %% [markdown]
# # Exercise_4.9_Part 1

# %% [markdown]
# ## Content :
# ### Step 3 : Import analysis libraries, as well as new customer data set as a dataframe
# ### Step 4: Wrangle Data
# ### Step 5: Data Quality and Consistency checks
# ### Step 6: Merge Customer data into rest of preapred Instacart data
# ### Step 8 Exporting dataframes

# %% [markdown]
# ## Step 3 : Import analysis libraries, as well as  new customer data set as a dataframe

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# assign path
path = r'C:\Users\Bilel\Desktop\data_analyst_Carrer Foundry\Data Immersion\07-12-24 Instacart Basket Analysis'

# %%
# Import new customer data set from the 'Original Data' folder as a dataframe
cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
# Preview the newly imported dataframe 
cust.head(10)
# Out:
#    user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# ...

# %%
# Check the dimensions of the dataframe
cust.shape
# Out:
# (206209, 10)

# %% [markdown]
# ## Step 4: Wrangle Data

# %%
# rename First Name as first_name
cust.rename(columns={'First Name' : 'first_name'}, inplace =True)

# %%
# rename Surnam as last_name
cust.rename(columns={'Surnam' : 'last_name'}, inplace =True)

# %%
# rename Gender as gender
cust.rename(columns={'Gender' : 'gender'}, inplace =True)

# %%
# rename STATE as state
cust.rename(columns={'STATE' : 'state'}, inplace =True)

# %%
# rename Age as age
cust.rename(columns={'Age' : 'age'}, inplace =True)

# %%
# rename n_dependants as number_of_dependants
cust.rename(columns={'n_dependants' : 'number_of_dependants'}, inplace =True)

# %%
# rename fam_status as family_status
cust.rename(columns={'fam_status' : 'family_status'}, inplace =True)

# %%
cust.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %% [markdown]
# ## Step 5: Data Quality and Consistency checks

# %%
# Check data types
cust.dtypes
# Out:
# user_id                  int64
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependants     int64
# family_status           object
# income                   int64
# dtype: object

# %%
cust.describe()
# Out:
#              user_id            age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %% [markdown]
# It doesnt look like there are obvious outliers, all numbers look reasonable.

# %%
# Check for mixed-type data
for col in cust.columns.tolist():
  weird = (cust[[col]].map(type) != cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (cust[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# assign 'first_name' to type string
cust['first_name']=cust['first_name'].astype('str')

# %%
# Verfication for mixed-type data
for col in cust.columns.tolist():
  weird = (cust[[col]].map(type) != cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (cust[weird]) > 0:
    print (col)

# %% [markdown]
# There is no mixed-type data after converting "first_name" column to "string"

# %%
# Check for missing values
cust.isnull().sum()
# Out:
# user_id                 0
# first_name              0
# last_name               0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# number_of_dependants    0
# family_status           0
# income                  0
# dtype: int64

# %% [markdown]
# There is no missing values in the dataframe

# %%
# Check for duplicates
num_dups= cust.duplicated().sum()

# %%
num_dups
# Out:
# 0

# %%
dups = cust[cust.duplicated()]

# %%
dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, number_of_dependants, family_status, income]
# Index: []

# %% [markdown]
# There is no duplicated rows  in the dataframe

# %% [markdown]
# ## Step 6: Merge Customer data into rest of preapred Instacart data

# %%
# Import updated  Instacart DF
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_grouped_corrected.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
# rechek  data type before merging
ords_prods_merge.dtypes
# Out:
# order_id                    int32
# user_id                     int32
# order_number                 int8
# orders_day_of_week           int8
# order_hour_of_day            int8
# days_since_prior_order    float32
# new_customer                 bool
# product_id                  int32
# add_to_cart_order           int32
# reordered                    int8
# product_name               object
# aisle_id                    int64
# department_id               int64
# prices                    float64
# price_range_loc            object
# busiest_day                object
# Busiest_days               object
# busiest_period_of_day      object
# max_order                    int8
# loyalty_flag               object
# avg_prods_price           float64
# spending_flag              object
# customer_frequency        float32
# order_frequency_flag       object
# dtype: object

# %%
cust.dtypes
# Out:
# user_id                  int64
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependants     int64
# family_status           object
# income                   int64
# dtype: object

# %%
# changing "user_id" data type in "cust" datafrme to int32 like in "ords_prods_merge" datafrme
cust['user_id']=cust['user_id'].astype('int32')

# %%
cust.dtypes
# Out:
# user_id                  int32
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependants     int64
# family_status           object
# income                   int64
# dtype: object

# %% [markdown]
# Now the key columns are the same data type

# %%
# Merge the two dataframes using the column 'user_id' as the shared column with the default join (inner)
custs_ords_prods = ords_prods_merge.merge(cust, on = 'user_id', indicator = True)

# %%
custs_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered  ... first_name  last_name  gender    state age date_joined  \
# ...

# %%
# Display all colunms
pd.set_option('display.max_columns', None)

# %%
custs_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# Check shape of newly merged dataframe
custs_ords_prods.shape
# Out:
# (32404859, 34)

# %%
# Check inner join value counts
custs_ords_prods['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Check data-types
custs_ords_prods.dtypes
# Out:
# order_id                     int32
# user_id                      int32
# order_number                  int8
# orders_day_of_week            int8
# order_hour_of_day             int8
# days_since_prior_order     float32
# new_customer                  bool
# product_id                   int32
# add_to_cart_order            int32
# reordered                     int8
# product_name                object
# aisle_id                     int64
# department_id                int64
# prices                     float64
# price_range_loc             object
# busiest_day                 object
# Busiest_days                object
# busiest_period_of_day       object
# max_order                     int8
# loyalty_flag                object
# avg_prods_price            float64
# spending_flag               object
# customer_frequency         float32
# order_frequency_flag        object
# first_name                  object
# last_name                   object
# gender                      object
# ...

# %%
# drop "_merge" column before exporting
custs_ords_prods =custs_ords_prods.drop(columns=['_merge'])

# %%
custs_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %% [markdown]
# ## Step 8 Exporting dataframes

# %%
# export checked file
cust.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'customers_checked.csv'))

# %%
# export the new dataframe as a pickle file
custs_ords_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged.pkl'))
